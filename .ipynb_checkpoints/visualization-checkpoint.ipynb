# %%
import pandas as pd
import numpy as np
import json
from matplotlib import pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
mdls = ['mip', 'cp']
res_ = []
for mdl in mdls:
     with open("./results/total_results_{}.json".format(mdl), "r") as f:
        raw = json.load(f)
        raw = pd.DataFrame(raw)
        raw['mdl_name'] = mdl
        raw['PARAMS'] = raw['NUM_COLORS'].map(str) + ',' + raw['NUM_ITEMS'].map(str) + ','  + raw['BIN_SIZE'].map(str) + ','  + raw['DISCREPANCY'].map(str)
#         raw = raw.set_index('PARAMS')
        res_.append(raw)
         
res = pd.concat(res_)
res['STATUS'] = res['STATUS'].str.lower()

# %%
res_across = pd.concat(res_,
    axis=1,
    join="outer",
    names=['mip','cp'])

# %%
res = res[res['NUM_COLORS'] >= 16]
res = res[res['NUM_ITEMS'] >= 16]
res = res[res['BIN_SIZE'] >= 16]


res
# Out:
#      NUM_COLORS  NUM_ITEMS  BIN_SIZE  DISCREPANCY  OBJ_VAL  OBJ_BOUND  \
# 0             4          8         8         0.00      4.0        4.0
# 1             4          8         8         0.50      4.0        4.0
# 2             4         16        16         0.25      5.0        5.0
# 3             4          8         8         0.25      3.0        3.0
# 4             4          8         8         0.75      2.0        2.0
# ..          ...        ...       ...          ...      ...        ...
# 123          32        128         8         0.75     24.0       24.0
# 124          32        128        16         0.00     67.0       67.0
# 125          32        128        16         0.50     35.0       35.0
# 126          32        128        16         0.25     51.0       51.0
# 127          32        128        16         0.75     21.0       21.0
#
#      OBJ_GAP  NUM_VARS  NUM_CONSTRS  SOLVE_TIME                    STATUS  \
# 0        0.0        72          159    0.078000  integer optimal solution
# 1        0.0        72          167    0.047000  integer optimal solution
# 2        0.0       272          735    0.156000  integer optimal solution
# 3        0.0        72          143    0.110000  integer optimal solution
# 4        0.0        72          127    0.031000  integer optimal solution
# ..       ...       ...          ...         ...                       ...
# 123      0.0      4352          395    0.613563                   optimal
# 124      0.0      4352          428    4.031117                   optimal
# 125      0.0      4352          400    1.421455                   optimal
# 126      0.0      4352          399    8.365255                   optimal
# 127      0.0      4352          434    0.676892                   optimal
#
#     mdl_name          PARAMS
# 0        mip       4,8,8,0.0
# 1        mip       4,8,8,0.5
# 2        mip    4,16,16,0.25
# 3        mip      4,8,8,0.25
# 4        mip      4,8,8,0.75
# ..       ...             ...
# 123       cp   32,128,8,0.75
# 124       cp   32,128,16,0.0
# 125       cp   32,128,16,0.5
# 126       cp  32,128,16,0.25
# 127       cp  32,128,16,0.75
#
# [288 rows x 13 columns]

# %%
p_mip = res[res['mdl_name'] == 'mip'][['PARAMS','OBJ_VAL', 'STATUS']]
p_cp = res[res['mdl_name'] == 'cp'][['PARAMS','OBJ_VAL', 'STATUS']]

p = pd.merge(p_mip, p_cp, on='PARAMS')
p
# Out:
#              PARAMS  OBJ_VAL_x                  STATUS_x  OBJ_VAL_y STATUS_y
# 0         4,8,8,0.0        4.0  integer optimal solution        4.0  optimal
# 1         4,8,8,0.5        4.0  integer optimal solution        4.0  optimal
# 2      4,16,16,0.25        5.0  integer optimal solution        5.0  optimal
# 3        4,8,8,0.25        3.0  integer optimal solution        3.0  optimal
# 4        4,8,8,0.75        2.0  integer optimal solution        2.0  optimal
# ..              ...        ...                       ...        ...      ...
# 123  32,128,16,0.25       51.0  integer optimal solution       51.0  optimal
# 124  32,128,16,0.75       21.0  integer optimal solution       21.0  optimal
# 125   4,128,16,0.75       21.0  integer optimal solution       21.0  optimal
# 126       8,8,8,0.0        5.0  integer optimal solution        5.0  optimal
# 127       8,8,8,0.5        2.0  integer optimal solution        2.0  optimal
#
# [128 rows x 5 columns]

# %%
len(p_mip) == len(p_cp)
# Out:
# False

# %%
gph = plt.figure(figsize=(10,5))
params = list(res['PARAMS'].unique())
num_instances_feas = [5*i for i in range(1,5)]

colors = ['r','b','g']

for i, mdl_name in enumerate(res.mdl_name.unique()):
    print(i, mdl_name)
    
    res_mdl = res[res['mdl_name'] == mdl_name]
    res_mdl = res_mdl[res_mdl['STATUS'].str.contains("optimal")]
    res_mdl = res_mdl.sort_values(['SOLVE_TIME'])
    solve_times = res_mdl['SOLVE_TIME'].unique()
    counts = []
    for t in solve_times:
        counts.append(res_mdl[res_mdl['SOLVE_TIME'] <= t].shape[0])
    
    plt.step(list(solve_times), counts, "{}*-".format(colors[i]), where='post')
    
plt.legend(res.mdl_name.unique(), loc='lower right', fontsize= 20)
plt.xlabel("Timeout (seconds)", fontsize= 20)
plt.ylabel("# of instances at optimality", fontsize= 20)
# gph.plot(res.groupby(["mdl_name", "timeout"]['obj'].count()), DF0.x, DF0.y, "r.--")
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
# Out:
# 0 mip
# 1 cp

# %%
solve_times
# Out:
# array([3.12299728e-02, 3.12452316e-02, 3.12504768e-02, 3.12623978e-02,
#        3.12750340e-02, 4.68666553e-02, 5.61044216e-02, 6.24709129e-02,
#        6.25033379e-02, 7.81142712e-02, 7.81149864e-02, 7.81154633e-02,
#        7.81517029e-02, 8.08339119e-02, 9.37516689e-02, 9.50846672e-02,
#        9.95674133e-02, 1.10420227e-01, 1.10605478e-01, 1.11766100e-01,
#        1.24998808e-01, 1.25005722e-01, 1.40611410e-01, 1.40622854e-01,
#        1.40631914e-01, 1.40653610e-01, 1.44285440e-01, 1.57458305e-01,
#        1.82740927e-01, 1.88783169e-01, 2.04379559e-01, 2.15433598e-01,
#        2.18772888e-01, 2.19951391e-01, 2.35698462e-01, 2.50023603e-01,
#        2.65603781e-01, 2.96866894e-01, 2.98147917e-01, 3.13839674e-01,
#        3.45009327e-01, 3.45149040e-01, 3.90586853e-01, 4.39369917e-01,
#        4.85575914e-01, 5.46855688e-01, 5.46925545e-01, 5.56808710e-01,
#        5.64242840e-01, 5.68202496e-01, 6.13562584e-01, 6.47160530e-01,
#        6.76891565e-01, 6.87485933e-01, 7.05977440e-01, 7.55263090e-01,
#        8.20370913e-01, 8.93068075e-01, 1.36018085e+00, 1.36289859e+00,
#        1.42145538e+00, 1.45672798e+00, 2.22802615e+00, 2.31837082e+00,
#        3.36056161e+00, 3.44326878e+00, 3.93849897e+00, 3.94415665e+00,
#        3.99594665e+00, 4.03111672e+00, 4.54162574e+00, 6.39558291e+00,
#        8.36525536e+00, 1.65186448e+01, 1.68507037e+01, 1.73902512e+01,
#        3.16875405e+01, 3.60113558e+03, 3.60153101e+03])
